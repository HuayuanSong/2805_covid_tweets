# %% [markdown]
# # Choosing Data
# In this notebook, we choose a subset of the "COVID-19 Twitter Dataset with Latent Topics, Sentiments and Emotions Attributes" dataset for the UK[1]. We do this since we have a limited amount of compute at our disposal. The full dataset contain tens of millions of rows.

# %%
import pandas as pd

# %%
# Import CSV data file
data = pd.read_csv("files/project_tweet_data_UK.csv", index_col=0)

# Check first five rows
data.head(5)
# Out:
#               tweet_ID    user_id keywords      tweet_timestamp  \
# 0  1234289474479239168  303154079    covid  2020-03-02 01:28:37
# 1  1234289531228237824  566536507    covid  2020-03-02 01:28:50
# 2  1234289658445664257  248819855    covid  2020-03-02 01:29:21
# 3  1234289759092191232  248819855    covid  2020-03-02 01:29:45
# 4  1234290038965506048  248819855    covid  2020-03-02 01:30:51
#
#    valence_intensity  fear_intensity  anger_intensity  happiness_intensity  \
# 0              0.380           0.516            0.454                0.207
# 1              0.765           0.289            0.248                0.638
# 2              0.399           0.566            0.388                0.232
# 3              0.380           0.612            0.411                0.218
# 4              0.408           0.585            0.412                0.253
#
#    sadness_intensity  sentiment emotion
# 0              0.458         -1       F
# 1              0.292          2       H
# ...

# %%
# Check last five rows
data.tail(5)
# Out:
#                     tweet_ID              user_id keywords  \
# 5983995  1310255378337345539             83881926    covid
# 5983996  1310255384830058497  1208765275878895617    covid
# 5983997  1310255391394201605  1149959365664882688    covid
# 5983998  1310255402123251714            351669443    covid
# 5983999  1310255409375125504             61737425    covid
#
#              tweet_timestamp  valence_intensity  fear_intensity  \
# 5983995  2020-09-27 16:30:00              0.453           0.348
# 5983996  2020-09-27 16:30:01              0.491           0.411
# 5983997  2020-09-27 16:30:03              0.438           0.372
# 5983998  2020-09-27 16:30:05              0.575           0.307
# 5983999  2020-09-27 16:30:07              0.347           0.461
#
#          anger_intensity  happiness_intensity  sadness_intensity  sentiment  \
# 5983995            0.375                0.333              0.367         -1
# ...

# %%
# Check shape
data.shape
# Out:
# (5984000, 11)

# %%
# Take initial subset
data_subset = data.head(4400000)

# %%
# Reset indicies
data_subset = data_subset.reset_index(drop=True)

# %%
# Inspect last five rows
data_subset.tail(5)
# Out:
#                     tweet_ID    user_id keywords      tweet_timestamp  \
# 4399995  1285836228324200449  471414613    covid  2020-07-22 07:17:01
# 4399996  1285836271579992065  730944914    covid  2020-07-22 07:17:11
# 4399997  1285836306803757057   83547263    covid  2020-07-22 07:17:19
# 4399998  1285836317042135040  421047121    covid  2020-07-22 07:17:22
# 4399999  1285836343369662465  256027136    covid  2020-07-22 07:17:28
#
#          valence_intensity  fear_intensity  anger_intensity  \
# 4399995              0.616           0.283            0.342
# 4399996              0.483           0.455            0.471
# 4399997              0.475           0.516            0.400
# 4399998              0.388           0.519            0.550
# 4399999              0.430           0.474            0.485
#
#          happiness_intensity  sadness_intensity  sentiment emotion
# 4399995                0.458              0.291          1       H
# ...

# %%
## We still have too many rows.. ##

# Take every 6th row and discard the rest
data_new = data_subset.iloc[::6, :]

# Reset indicies
data_new = data_new.reset_index(drop=True)

# Inspect shape of new subset DataFrame
data_new.shape
# Out:
# (733334, 11)

# %%
# Save to CSV
data_new.to_csv("files/project_tweet_data_final_UK.csv")

# %%
# Import saved CSV file to inspect that it is in order
data_import = pd.read_csv("files/project_tweet_data_final_UK.csv",index_col=0)

# %%
# Inspect first five elements
data_import.head(5)
# Out:
#               tweet_ID    user_id keywords      tweet_timestamp  \
# 0  1234289474479239168  303154079    covid  2020-03-02 01:28:37
# 1  1234290271774543872  248819855    covid  2020-03-02 01:31:47
# 2  1234291397202776065  248819855    covid  2020-03-02 01:36:15
# 3  1234292673260879872  447663369   corona  2020-03-02 01:41:20
# 4  1234293534498414592  406164260    covid  2020-03-02 01:44:45
#
#    valence_intensity  fear_intensity  anger_intensity  happiness_intensity  \
# 0              0.380           0.516            0.454                0.207
# 1              0.380           0.611            0.412                0.218
# 2              0.408           0.505            0.422                0.218
# 3              0.448           0.566            0.419                0.267
# 4              0.575           0.465            0.306                0.390
#
#    sadness_intensity  sentiment emotion
# 0              0.458         -1       F
# 1              0.460         -1       F
# ...

# %%
# Inspect final five rows
data_import.tail(5)

## Looks OK! ##
# Out:
#                    tweet_ID              user_id keywords  \
# 733329  1285835856650043393            334091760    covid
# 733330  1285835987424337921             75508547   corona
# 733331  1285836106496385025  1096478949725614080    covid
# 733332  1285836204559290369            162753440    covid
# 733333  1285836317042135040            421047121    covid
#
#             tweet_timestamp  valence_intensity  fear_intensity  \
# 733329  2020-07-22 07:15:32              0.587           0.377
# 733330  2020-07-22 07:16:03              0.250           0.507
# 733331  2020-07-22 07:16:32              0.325           0.537
# 733332  2020-07-22 07:16:55              0.359           0.563
# 733333  2020-07-22 07:17:22              0.388           0.519
#
#         anger_intensity  happiness_intensity  sadness_intensity  sentiment  \
# 733329            0.331                0.363              0.324          1
# 733330            0.608                0.141              0.508         -2
# ...

# %% [markdown]
# # References

# %% [markdown]
# [1] Gupta, Raj, Vishwanath, Ajay, and Yang, Yinping. COVID-19 Twitter Dataset with Latent Topics, Sentiments and Emotions Attributes. Ann Arbor, MI: Inter-university Consortium for Political and Social Research [distributor], 2022-06-25. https://doi.org/10.3886/E120321V12 <br>
# (Link to data: https://www.openicpsr.org/openicpsr/project/120321/version/V12/view?path=/openicpsr/120321/fcr:versions/V12/Twitter-COVID-dataset---June2022/tweetid_userid_keyword_sentiments_emotions_United-Kingdom.zip&type=file)

# %%
import pandas as pd
import networkx as nx
import numpy as np
import re

# %%
uk_df = pd.read_csv("files/cleaned_twitter_data_UK.csv", index_col = 0, dtype={'user_id': str})
# Out:
# /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
uk_df
# Out:
#                    tweet_ID              user_id keywords  \
# 1       1234290271774543872            248819855    covid
# 2       1234291397202776065            248819855    covid
# 3       1234292673260879872            447663369   corona
# 5       1234294077564375040           1903820431   corona
# 6       1234294853330182144             20973388    covid
# ...                     ...                  ...      ...
# 733329  1285835856650043393            334091760    covid
# 733330  1285835987424337921             75508547   corona
# 733331  1285836106496385025  1096478949725614080    covid
# 733332  1285836204559290369            162753440    covid
# 733333  1285836317042135040            421047121    covid
#
#             tweet_timestamp  valence_intensity  fear_intensity  \
# 1       2020-03-02 01:31:47              0.380           0.611
# 2       2020-03-02 01:36:15              0.408           0.505
# 3       2020-03-02 01:41:20              0.448           0.566
# 5       2020-03-02 01:46:54              0.490           0.529
# 6       2020-03-02 01:49:59              0.406           0.613
# ...                     ...                ...             ...
# 733329  2020-07-22 07:15:32              0.587           0.377
# 733330  2020-07-22 07:16:03              0.250           0.507
# 733331  2020-07-22 07:16:32              0.325           0.537
# 733332  2020-07-22 07:16:55              0.359           0.563
# 733333  2020-07-22 07:17:22              0.388           0.519
#
#         anger_intensity  happiness_intensity  sadness_intensity  sentiment  \
# 1                 0.412                0.218              0.460       -1.0
# 2                 0.422                0.218              0.417       -1.0
# 3                 0.419                0.267              0.415       -1.0
# 5                 0.447                0.426              0.475        0.0
# 6                 0.458                0.271              0.460       -1.0
# ...                 ...                  ...                ...        ...
# 733329            0.331                0.363              0.324        1.0
# 733330            0.608                0.141              0.508       -2.0
# 733331            0.504                0.186              0.483       -1.0
# 733332            0.556                0.287              0.438       -1.0
# 733333            0.550                0.238              0.460       -1.0
#
#        emotion                                              tweet  len_content
# 1            F  HEALTH EMERGENCY / INTERNATIONAL COVID-19 CORO...          8.0
# 2            F  HEALTH EMERGENCY / INTERNATIONAL COVID-19 CORO...         23.0
# 3            F  Corruption scaring corona virus from Africa &g...          7.0
# 5          NaN  Starting up with a cold and lightly concerned ...         41.0
# 6            F  The UK government is considering all options, ...         27.0
# ...        ...                                                ...          ...
# 733329       H  VDMA highlights textile machinery role in Covi...          9.0
# 733330       A  @sidudeja But why would you want anyone dead? ...         24.0
# 733331       F  @LondonPehwb @grantshapps Absolutely.  However...         49.0
# 733332       F  So I realised this morning I feel like a #Chal...         35.0
# 733333       A  Israelis protest against Netanyahu, gov't hand...         17.0
#
# [593239 rows x 13 columns]

# %%
def find_mention(tweet):
    pattern = r'@([A-Za-z0-9_]+)'
    match = re.findall(pattern, tweet)

    return match

# %%
uk_df = uk_df.dropna(subset = ["tweet"])

# %%
uk_df
# Out:
#                    tweet_ID              user_id keywords  \
# 0       1234290271774543872            248819855    covid
# 1       1234291397202776065            248819855    covid
# 2       1234292673260879872            447663369   corona
# 3       1234294077564375040           1903820431   corona
# 4       1234294853330182144             20973388    covid
# ...                     ...                  ...      ...
# 593234  1285835856650043393            334091760    covid
# 593235  1285835987424337921             75508547   corona
# 593236  1285836106496385025  1096478949725614080    covid
# 593237  1285836204559290369            162753440    covid
# 593238  1285836317042135040            421047121    covid
#
#             tweet_timestamp  valence_intensity  fear_intensity  \
# 0       2020-03-02 01:31:47              0.380           0.611
# 1       2020-03-02 01:36:15              0.408           0.505
# 2       2020-03-02 01:41:20              0.448           0.566
# 3       2020-03-02 01:46:54              0.490           0.529
# 4       2020-03-02 01:49:59              0.406           0.613
# ...                     ...                ...             ...
# 593234  2020-07-22 07:15:32              0.587           0.377
# 593235  2020-07-22 07:16:03              0.250           0.507
# 593236  2020-07-22 07:16:32              0.325           0.537
# 593237  2020-07-22 07:16:55              0.359           0.563
# 593238  2020-07-22 07:17:22              0.388           0.519
#
#         anger_intensity  happiness_intensity  sadness_intensity  sentiment  \
# 0                 0.412                0.218              0.460       -1.0
# 1                 0.422                0.218              0.417       -1.0
# 2                 0.419                0.267              0.415       -1.0
# 3                 0.447                0.426              0.475        0.0
# 4                 0.458                0.271              0.460       -1.0
# ...                 ...                  ...                ...        ...
# 593234            0.331                0.363              0.324        1.0
# 593235            0.608                0.141              0.508       -2.0
# 593236            0.504                0.186              0.483       -1.0
# 593237            0.556                0.287              0.438       -1.0
# 593238            0.550                0.238              0.460       -1.0
#
#        emotion                                              tweet  len_content
# 0            F  HEALTH EMERGENCY / INTERNATIONAL COVID-19 CORO...          8.0
# 1            F  HEALTH EMERGENCY / INTERNATIONAL COVID-19 CORO...         23.0
# 2            F  Corruption scaring corona virus from Africa &g...          7.0
# 3          NaN  Starting up with a cold and lightly concerned ...         41.0
# 4            F  The UK government is considering all options, ...         27.0
# ...        ...                                                ...          ...
# 593234       H  VDMA highlights textile machinery role in Covi...          9.0
# 593235       A  @sidudeja But why would you want anyone dead? ...         24.0
# 593236       F  @LondonPehwb @grantshapps Absolutely.  However...         49.0
# 593237       F  So I realised this morning I feel like a #Chal...         35.0
# 593238       A  Israelis protest against Netanyahu, gov't hand...         17.0
#
# [593237 rows x 13 columns]

# %%
uk_df = uk_df.reset_index(drop = True)

# %%
np.sum(uk_df['tweet'].isnull().values)
# Out:
# 0

# %%
uk_df['mentions'] = uk_df['tweet'].apply(find_mention)

# %%
uk_df['mentions']
# Out:
# 0                                 []
# 1                                 []
# 2                                 []
# 3                                 []
# 4                       [darrenadam]
#                      ...
# 593232                            []
# 593233                    [sidudeja]
# 593234    [LondonPehwb, grantshapps]
# 593235                            []
# 593236                            []
# Name: mentions, Length: 593237, dtype: object

# %%
mentions_df = uk_df[uk_df['mentions'].map(lambda d: len(d)) > 0]

# %%
mentions_df
# Out:
#                    tweet_ID              user_id keywords  \
# 4       1234294853330182144             20973388    covid
# 7       1234305116506861568            442831126    covid
# 9       1234310189404348417  1157949934949347328    wuhan
# 16      1234318241431990272             16027848    covid
# 18      1234321940401270785            282914879    covid
# ...                     ...                  ...      ...
# 593226  1285835534766673923   916192094330507264    covid
# 593227  1285835650059636736           3057049653    covid
# 593228  1285835723740856321            216650916    covid
# 593233  1285835987424337921             75508547   corona
# 593234  1285836106496385025  1096478949725614080    covid
#
#             tweet_timestamp  valence_intensity  fear_intensity  \
# 4       2020-03-02 01:49:59              0.406           0.613
# 7       2020-03-02 02:30:46              0.665           0.326
# 9       2020-03-02 02:50:56              0.371           0.525
# 16      2020-03-02 03:22:55              0.329           0.587
# 18      2020-03-02 03:37:37              0.514           0.364
# ...                     ...                ...             ...
# 593226  2020-07-22 07:14:15              0.629           0.306
# 593227  2020-07-22 07:14:43              0.440           0.399
# 593228  2020-07-22 07:15:00              0.598           0.336
# 593233  2020-07-22 07:16:03              0.250           0.507
# 593234  2020-07-22 07:16:32              0.325           0.537
#
#         anger_intensity  happiness_intensity  sadness_intensity  sentiment  \
# 4                 0.458                0.271              0.460       -1.0
# 7                 0.373                0.443              0.325        1.0
# 9                 0.426                0.234              0.455       -1.0
# 16                0.570                0.138              0.474       -1.0
# 18                0.370                0.361              0.360        0.0
# ...                 ...                  ...                ...        ...
# 593226            0.315                0.454              0.285        1.0
# 593227            0.464                0.245              0.436       -1.0
# 593228            0.330                0.406              0.318        1.0
# 593233            0.608                0.141              0.508       -2.0
# 593234            0.504                0.186              0.483       -1.0
#
#        emotion                                              tweet  \
# 4            F  The UK government is considering all options, ...
# 7            H  @Grummz An article for you after yesterday's m...
# 9            F  @fascinatorfun So question is why the mortalit...
# 16           F  Video: #ToxicTories try to hide damage to NHS ...
# 18         NaN  @dray24574721 @BNODesk This, from S Korea afte...
# ...        ...                                                ...
# 593226       H  #Reboot weekends have started up again.  #covi...
# 593227       A  @Gnomeponders My daughter and partner are both...
# 593228       H  Join on September 1st @ 5pm for a HealthChat w...
# 593233       A  @sidudeja But why would you want anyone dead? ...
# 593234       F  @LondonPehwb @grantshapps Absolutely.  However...
#
#         len_content                    mentions
# 4              27.0                [darrenadam]
# 7              18.0                    [Grummz]
# 9              14.0             [fascinatorfun]
# 16             27.0                 [skwawkbox]
# 18             15.0     [dray24574721, BNODesk]
# ...             ...                         ...
# 593226         24.0                [actressann]
# 593227         20.0              [Gnomeponders]
# 593228         41.0                 [RoyLilley]
# 593233         24.0                  [sidudeja]
# 593234         49.0  [LondonPehwb, grantshapps]
#
# [271096 rows x 14 columns]

# %%
mentions_df.iloc[0]
# Out:
# tweet_ID                                             1234294853330182144
# user_id                                                         20973388
# keywords                                                           covid
# tweet_timestamp                                      2020-03-02 01:49:59
# valence_intensity                                                  0.406
# fear_intensity                                                     0.613
# anger_intensity                                                    0.458
# happiness_intensity                                                0.271
# sadness_intensity                                                   0.46
# sentiment                                                           -1.0
# emotion                                                                F
# tweet                  The UK government is considering all options, ...
# len_content                                                         27.0
# mentions                                                    [darrenadam]
# Name: 4, dtype: object

# %%
mentions_df.to_csv('files/mentions_UK.csv')

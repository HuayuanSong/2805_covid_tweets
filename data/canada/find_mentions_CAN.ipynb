# %%
import pandas as pd
import networkx as nx
import numpy as np
import re

# %%
uk_df = pd.read_csv("files/cleaned_twitter_data_CAN.csv", index_col = 0, dtype={'user_id': str})
# Out:
# /Users/huayuan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
uk_df
# Out:
#             tweet_ID              user_id keywords      tweet_timestamp  \
# 0       1.221960e+18             13752142    wuhan  2020-01-28 00:55:15
# 1       1.221971e+18  1031691314536935424    wuhan  2020-01-28 01:38:26
# 2       1.221976e+18             31473811    wuhan  2020-01-28 01:57:58
# 3       1.221985e+18              1072771    wuhan  2020-01-28 02:36:25
# 4       1.221990e+18            401098282    wuhan  2020-01-28 02:53:08
# ...              ...                  ...      ...                  ...
# 616792  1.285836e+18            282716700    covid  2020-07-22 07:14:08
# 616793  1.285836e+18           1497174692    covid  2020-07-22 07:15:29
# 616794  1.285836e+18            620886049    covid  2020-07-22 07:15:38
# 616795  1.285836e+18  1044971320998588417    covid  2020-07-22 07:16:52
# 616796  1.285836e+18           2388168248    covid  2020-07-22 07:17:29
#
#         valence_intensity  fear_intensity  anger_intensity  \
# ...

# %%
def find_mention(tweet):
    pattern = r'@([A-Za-z0-9_]+)'
    match = re.findall(pattern, tweet)

    return match

# %%
uk_df = uk_df.dropna(subset = ["tweet"])

# %%
uk_df
# Out:
#             tweet_ID              user_id keywords      tweet_timestamp  \
# 0       1.221960e+18             13752142    wuhan  2020-01-28 00:55:15
# 1       1.221971e+18  1031691314536935424    wuhan  2020-01-28 01:38:26
# 2       1.221976e+18             31473811    wuhan  2020-01-28 01:57:58
# 3       1.221985e+18              1072771    wuhan  2020-01-28 02:36:25
# 4       1.221990e+18            401098282    wuhan  2020-01-28 02:53:08
# ...              ...                  ...      ...                  ...
# 616792  1.285836e+18            282716700    covid  2020-07-22 07:14:08
# 616793  1.285836e+18           1497174692    covid  2020-07-22 07:15:29
# 616794  1.285836e+18            620886049    covid  2020-07-22 07:15:38
# 616795  1.285836e+18  1044971320998588417    covid  2020-07-22 07:16:52
# 616796  1.285836e+18           2388168248    covid  2020-07-22 07:17:29
#
#         valence_intensity  fear_intensity  anger_intensity  \
# ...

# %%
uk_df = uk_df.reset_index(drop = True)

# %%
np.sum(uk_df['tweet'].isnull().values)
# Out:
# 0

# %%
uk_df['mentions'] = uk_df['tweet'].apply(find_mention)

# %%
uk_df['mentions']
# Out:
# 0         [maurerbot, JustinTrudeau]
# 1                          [BNONews]
# 2                       [AliEhsassi]
# 3                       [GoogleNews]
# 4                    [Franktmcveety]
#                      ...
# 733085                            []
# 733086                     [660NEWS]
# 733087                            []
# 733088                   [WorldBank]
# 733089                            []
# Name: mentions, Length: 733090, dtype: object

# %%
mentions_df = uk_df[uk_df['mentions'].map(lambda d: len(d)) > 0]

# %%
mentions_df
# Out:
#             tweet_ID              user_id keywords      tweet_timestamp  \
# 0       1.221960e+18             13752142    wuhan  2020-01-28 00:55:15
# 1       1.221971e+18  1031691314536935424    wuhan  2020-01-28 01:38:26
# 2       1.221976e+18             31473811    wuhan  2020-01-28 01:57:58
# 3       1.221985e+18              1072771    wuhan  2020-01-28 02:36:25
# 4       1.221990e+18            401098282    wuhan  2020-01-28 02:53:08
# ...              ...                  ...      ...                  ...
# 733072  1.285832e+18             71669770    covid  2020-07-22 06:59:12
# 733073  1.285832e+18   790757502040305664    covid  2020-07-22 06:59:23
# 733082  1.285835e+18           2554092884    covid  2020-07-22 07:10:30
# 733086  1.285836e+18           1497174692    covid  2020-07-22 07:15:29
# 733088  1.285836e+18  1044971320998588417    covid  2020-07-22 07:16:52
#
#         valence_intensity  fear_intensity  anger_intensity  \
# ...

# %%
mentions_df.iloc[0]
# Out:
# tweet_ID                                           1221959892619218944.0
# user_id                                                         13752142
# keywords                                                           wuhan
# tweet_timestamp                                      2020-01-28 00:55:15
# valence_intensity                                                  0.409
# fear_intensity                                                     0.468
# anger_intensity                                                     0.53
# happiness_intensity                                                0.255
# sadness_intensity                                                  0.462
# sentiment                                                           -1.0
# emotion                                                                A
# tweet                  @maurerbot @JustinTrudeau There's already What...
# len_content                                                         28.0
# ...

# %%
mentions_df.to_csv('files/mentions_CAN.csv')
